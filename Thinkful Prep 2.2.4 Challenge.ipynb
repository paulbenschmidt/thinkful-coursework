# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#general index
hpi = pd.read_csv('House_Price_Indexes_Master.csv')
hpi.head()

#Chicago-Naperville-Arlington Heights index
hpi_il = hpi.loc[lambda df: hpi['place_name'] == 'Chicago-Naperville-Arlington Heights, IL (MSAD)']

#traditional and distress-free properties of IL
hpi_il_trad = hpi_il.loc[lambda df: hpi['hpi_type'] == 'traditional']
hpi_il_df = hpi_il.loc[lambda df: hpi['hpi_type'] == 'distress-free']

#sub-categories of traditional IL properties
hpi_il_trad_all_transactions = hpi_il_trad.loc[lambda df: hpi['hpi_flavor'] == 'all-transactions']
hpi_il_trad_expanded_data = hpi_il_trad.loc[lambda df: hpi['hpi_flavor'] == 'expanded-data']
hpi_il_trad_purchase_only = hpi_il_trad.loc[lambda df: hpi['hpi_flavor'] == 'purchase-only']

# %%
#Chicago-Naperville-Arlington Heights graph
#hpi_il_pd
hpi_il_pd = pd.DataFrame(hpi_il)
hpi_il_pd = hpi_il_pd.drop(['hpi_type', 'hpi_flavor', 'frequency', 'level', 'place_name', 'place_id'], axis=1)
hpi_il_pd.index = range(506)
hpi_il_pd.columns = ['Year', 'Quarter', 'NSA_Index', 'SA_Index']

print

plt.plot(hpi_il_pd['NSA_Index'], color='purple')
plt.ylim([0, 300])
plt.ylabel('NSA Index')
plt.xlabel('Year')
plt.title('House Price Index')
plt.show()

plt.scatter(x=hpi_il_pd['Year'], y=hpi_il_pd['NSA_Index'], color='purple')
plt.ylim([0, 300])
plt.ylabel('NSA Index')
plt.xlabel('Year')
plt.title('House Price Index')
plt.show()

# Seen below are two different plots: a line plot and a scatter plot. The line plot provides an inaccurate representation 
# of the data because it is doesn't account for the differences in pricing between the three different types of traditional
# properties and the one type of distress-free property.

# The second graph gives a more accurate representation because one year is able to have multiple data entries (unlike
# the line graph).

# One problem I had throughout was not being able to print the years with their quarters in order. Therefore, I simply used
# ranges for the x-axis.

# %%
#Chicago-Naperville-Arlington Heights graph for traditional
#hpi_il_trad
hpi_il_trad_pd = pd.DataFrame(hpi_il_trad)
hpi_il_trad_pd = hpi_il_trad_pd.drop(['hpi_type', 'hpi_flavor', 'frequency', 'level', 'place_name', 'place_id'], axis=1)
hpi_il_trad_pd.index = range(395)
hpi_il_trad_pd.columns = ['Year', 'Quarter', 'NSA_Index', 'SA_Index']

plt.plot(hpi_il_trad_pd['NSA_Index'], color='red')
plt.ylim([0, 300])
plt.ylabel('NSA Index')
plt.xlabel('Year')
plt.title('Traditional House Price Index')
plt.show()

plt.scatter(x=hpi_il_trad_pd['Year'], y=hpi_il_trad_pd['NSA_Index'], color='purple')
plt.ylim([0, 300])
plt.ylabel('NSA Index')
plt.xlabel('Year')
plt.title('Traditional House Price Index')
plt.show()

# The two plots below are the same as above - with the exception that these only deal with traditional house prices.

# %%
#Chicago-Naperville-Arlington Heights graph for distress-free
#hpi_il_df
hpi_il_df_pd = pd.DataFrame(hpi_il_df)
hpi_il_df_pd = hpi_il_df_pd.drop(['hpi_type', 'hpi_flavor', 'frequency', 'level', 'place_name', 'place_id'], axis=1)
hpi_il_df_pd.index = range(111)
hpi_il_df_pd.columns = ['Year', 'Quarter', 'NSA_Index', 'SA_Index']

df1['e'] = Series(np.random.randn(sLength), index=df1.index)

plt.plot(hpi_il_df_pd['NSA_Index'], color='green')
plt.ylim([0, 300])
plt.ylabel('NSA Index')
plt.xlabel('Year')
plt.title('Distress-Free House Price Index')
plt.show()

# The line chart below deals with distress-free house pricing. The data available is shorter than the above charts, so the
# range was limited to 111 (since I still couldn't find out how to change the x axis to the year).
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b47971d5c71e> in <module>
#       1 #Chicago-Naperville-Arlington Heights graph for distress-free
#       2 #hpi_il_df
# ----> 3 hpi_il_df_pd = pd.DataFrame(hpi_il_df)
#       4 hpi_il_df_pd = hpi_il_df_pd.drop(['hpi_type', 'hpi_flavor', 'frequency', 'level', 'place_name', 'place_id'], axis=1)
#       5 hpi_il_df_pd.index = range(111)
#
# NameError: name 'pd' is not defined

# %%
#Chicago-Naperville-Arlington Heights graph for traditional, all transactions
#hpi_il_trad_all_transactions
hpi_il_trad_all_transactions_pd = pd.DataFrame(hpi_il_trad_all_transactions)
hpi_il_trad_all_transactions_pd = hpi_il_trad_all_transactions_pd.drop(['hpi_type', 'hpi_flavor', 'frequency', 'level', 'place_name', 'place_id'], axis=1)
hpi_il_trad_all_transactions_pd.index = range(173)
hpi_il_trad_all_transactions_pd.columns = ['Year', 'Quarter', 'NSA_Index', 'SA_Index']

plt.plot(hpi_il_trad_all_transactions_pd['NSA_Index'], color='yellow')
plt.ylim([0, 300])
plt.ylabel('NSA Index')
plt.xlabel('Year')
plt.title('Traditional House Price Index for All Transactions')
plt.show()

# The line chart below deals with all transactions under traditional house pricing. The range here covers a greater 
# length of time than the stress-free housing - in fact, it spans the longest length of time.
# Range is from 1975-2018

# %%
#Chicago-Naperville-Arlington Heights graph for traditional, expanded data
#hpi_il_trad_expanded_data
hpi_il_trad_expanded_data_pd = pd.DataFrame(hpi_il_trad_expanded_data)
hpi_il_trad_expanded_data_pd = hpi_il_trad_expanded_data_pd.drop(['hpi_type', 'hpi_flavor', 'frequency', 'level', 'place_name', 'place_id'], axis=1)
hpi_il_trad_expanded_data_pd.index = range(111)
hpi_il_trad_expanded_data_pd.columns = ['Year', 'Quarter', 'NSA_Index', 'SA_Index']

plt.plot(hpi_il_trad_expanded_data_pd['NSA_Index'], color='brown')
plt.ylim([0, 300])
plt.ylabel('NSA Index')
plt.xlabel('Year')
plt.title('Traditional House Price Index for Expanded Data')
plt.show()

plt.scatter(x=hpi_il_trad_expanded_data_pd['Year'], y=hpi_il_trad_expanded_data_pd['NSA_Index'], color='brown')
plt.ylim([0, 300])
plt.ylabel('NSA Index')
plt.xlabel('Year')
plt.title('Traditional House Price Index for Expanded Data')
plt.show()

# The line chart below deals with distress-free house pricing. The data available is shorter than the above charts, so the
# range was limited to 111 (since I still couldn't find out how to change the x axis to the year).
# Range is from 1991-2018

# %%
#Chicago-Naperville-Arlington Heights graph for traditional, purchase only
#hpi_il_trad_purchase_only
hpi_il_trad_purchase_only_pd = pd.DataFrame(hpi_il_trad_purchase_only)
hpi_il_trad_purchase_only_pd = hpi_il_trad_purchase_only_pd.drop(['hpi_type', 'hpi_flavor', 'frequency', 'level', 'place_name', 'place_id'], axis=1)
hpi_il_trad_purchase_only_pd.index = range(111)
hpi_il_trad_purchase_only_pd.columns = ['Year', 'Quarter', 'NSA_Index', 'SA_Index']

plt.plot(hpi_il_trad_purchase_only_pd['NSA_Index'], color='black')
plt.ylim([0, 300])
plt.ylabel('NSA Index')
plt.xlabel('Year')
plt.title('Traditional House Price Index for Purchases Only')
plt.show()

# The line chart below deals with distress-free house pricing. The data available is shorter than the above charts, so the
# range was limited to 111 (since I still couldn't find out how to change the x axis to the year).
# Range is from 1991-2018

# %%
plt.figure(figsize=(20, 10))
plt.subplot(4, 4, 1)
plt.plot(hpi_il_df_pd['NSA_Index'], color='green')
plt.ylim([0, 300])
plt.ylabel('NSA Index')
plt.xlabel('Year')
plt.title('Distress-Free House Price Index')
plt.show()

plt.figure(figsize=(20, 10))
plt.subplot(4, 4, 2)
plt.plot(hpi_il_trad_all_transactions_pd['NSA_Index'], color='yellow')
plt.ylim([0, 300])
plt.ylabel('NSA Index')
plt.xlabel('Year')
plt.title('Traditional House Price Index for All Transactions')
plt.show()

plt.figure(figsize=(20, 10))
plt.subplot(4, 4, 3)
plt.plot(hpi_il_trad_expanded_data_pd['NSA_Index'], color='brown')
plt.ylim([0, 300])
plt.ylabel('NSA Index')
plt.xlabel('Year')
plt.title('Traditional House Price Index for Expanded Data')
plt.show()

plt.figure(figsize=(20, 10))
plt.subplot(4, 4, 4)
plt.plot(hpi_il_trad_purchase_only_pd['NSA_Index'], color='black')
plt.ylim([0, 300])
plt.ylabel('NSA Index')
plt.xlabel('Year')
plt.title('Traditional House Price Index for Purchases Only')
plt.show()

# %%
plt.plot(hpi_il_df_pd['NSA_Index'], color='green')
plt.plot(hpi_il_trad_all_transactions_pd['NSA_Index'], color='yellow')
plt.plot(hpi_il_trad_expanded_data_pd['NSA_Index'], color='brown')
plt.plot(hpi_il_trad_purchase_only_pd['NSA_Index'], color='black')
plt.ylim([0, 300])
plt.ylabel('NSA Index')
plt.xlabel('Year')
plt.title('Combined')
plt.show()

# Since I didn't know how to set the x-axis to the year and quarter, I wasn't able to normalize this data and make the
# black, brown, and green lines begin in the year 1991 and have the yellow line begin in 1975. I know this will be an easy
# switch if I'm able to concatenate columns of year and quarter so that the year is the y ticks.

# %%
# Conclusion: This was very hard and pretty discouraging. I worked on this for about 5 hours. But it did help me learn
# the material.
